# %%
import pandas as pd

data = {
    "State": ["Maharashtra", "Karnataka", "Gujarat"],
    "Party": ["BJP", "INC", "BJP"],
    "Votes": [500000, 420000, 610000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#          State Party   Votes
# 0  Maharashtra   BJP  500000
# 1    Karnataka   INC  420000
# 2      Gujarat   BJP  610000
